# %%
# %matplotlib inline

import os
from PIL import Image
import cv2
import numpy as np
from numpy import random
import matplotlib.pyplot as plt
import torch
import albumentations as A
from albumentations.pytorch import ToTensor

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

SEED = 2020
seed_everything(SEED)

# %%
def transform_plot(image, transform, nrows=2, ncols=5):
    fig, axes = plt.subplots(nrows, ncols, figsize=(10, 4))
    axes = axes.flatten()
    for i, ax in enumerate(axes):
        augmented = transform(image=np.array(image))['image']
        ax.imshow(augmented, cmap='Greys')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# <a id="original"></a>
# # Original

# %%
import torchvision

dataset = torchvision.datasets.MNIST(root='./data', train=False, download=True, transform=None)
image, _ = dataset[0]
plt.imshow(np.array(image), cmap='Greys')
plt.show()

# %% [markdown]
# <a id="clahe"></a>
# # CLAHE

# %%
transform = A.Compose([
    A.CLAHE(clip_limit=4.0, tile_grid_size=(8, 8), p=1.0),
])

transform_plot(image, transform)

# %% [markdown]
# <a id="downscale"></a>
# # Downscale

# %%
transform = A.Compose([
    A.Downscale(scale_min=0.01, scale_max=0.99, interpolation=0, p=1.0),
])

transform_plot(image, transform)

# %% [markdown]
# <a id="equalize"></a>
# # Equalize

# %%
transform = A.Compose([
    A.Equalize(mode='cv', by_channels=True, mask=None, mask_params=(), p=1.0),
])

transform_plot(image, transform)

# %% [markdown]
# <a id="fromfloat"></a>
# # FromFloat

# %%
transform = A.Compose([
    A.FromFloat(dtype='uint16', max_value=None, p=1.0),
])

transform_plot(image, transform)

# %% [markdown]
# <a id="imagecompression"></a>
# # ImageCompression

# %%
transform = A.Compose([
    A.ImageCompression(quality_lower=99, quality_upper=100, p=1.0),
])

transform_plot(image, transform)

# %% [markdown]
# <a id="jpegcompression"></a>
# # JpegCompression

# %%
transform = A.Compose([
    A.JpegCompression(quality_lower=99, quality_upper=100, p=1.0),
])

transform_plot(image, transform)

# %% [markdown]
# <a id="invertimg"></a>
# # InvertImg

# %%
transform = A.Compose([
    A.InvertImg(p=1.0),
])

transform_plot(image, transform)

# %% [markdown]
# <a id="multiplicativenoise"></a>
# # MultiplicativeNoise

# %%
transform = A.Compose([
    A.MultiplicativeNoise(multiplier=(0.9, 1.1), per_channel=False, elementwise=False, p=1.0),
])

transform_plot(image, transform)

# %% [markdown]
# <a id="posterize"></a>
# # Posterize

# %%
transform = A.Compose([
    A.Posterize(num_bits=4, p=1.0),
])

transform_plot(image, transform)

# %% [markdown]
# <a id="randombrightnesscontrast"></a>
# # RandomBrightnessContrast

# %%
transform = A.Compose([
    A.RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, brightness_by_max=True, p=1.0),
])

transform_plot(image, transform)

# %% [markdown]
# <a id="randombrightness"></a>
# # RandomBrightness

# %%
transform = A.Compose([
    A.RandomBrightness(limit=0.2, p=1.0),
])

transform_plot(image, transform)

# %% [markdown]
# <a id="randomcontrast"></a>
# # RandomContrast

# %%
transform = A.Compose([
    A.RandomContrast(limit=0.2, p=1.0),
])

transform_plot(image, transform)

# %% [markdown]
# <a id="randomgamma"></a>
# # RandomGamma

# %%
transform = A.Compose([
    A.RandomGamma(gamma_limit=(80, 120), p=1.0),
])

transform_plot(image, transform)

# %% [markdown]
# <a id="solarize"></a>
# # Solarize

# %%
transform = A.Compose([
    A.Solarize(threshold=128, p=1.0),
])

transform_plot(image, transform)

# %% [markdown]
# <a id="tofloat"></a>
# # ToFloat

# %%
transform = A.Compose([
    A.ToFloat(max_value=None, p=1.0),
])

transform_plot(image, transform)

# %% [markdown]
# <a id="elastictransform"></a>
# # ElasticTransform

# %%
transform = A.Compose([
    A.ElasticTransform(alpha=1, sigma=1, alpha_affine=1, interpolation=1, border_mode=4, value=None, mask_value=None, p=1.0),
])

transform_plot(image, transform)

# %% [markdown]
# <a id="griddistortion"></a>
# # GridDistortion

# %%
transform = A.Compose([
    A.GridDistortion(num_steps=5, distort_limit=0.3, interpolation=1, border_mode=4, value=None, mask_value=None, p=1.0),
])

transform_plot(image, transform)

# %% [markdown]
# <a id="opticaldistortion"></a>
# # OpticalDistortion

# %%
transform = A.Compose([
    A.OpticalDistortion(distort_limit=0.05, shift_limit=0.05, interpolation=1, border_mode=4, value=None, mask_value=None, p=1.0),
])

transform_plot(image, transform)

# %% [markdown]
# <a id="randomgridshuffle"></a>
# # RandomGridShuffle

# %%
transform = A.Compose([
    A.RandomGridShuffle(grid=(3, 3), p=1.0),
])

transform_plot(image, transform)

# %% [markdown]
# <a id="padifneeded"></a>
# # PadIfNeeded

# %%
transform = A.Compose([
    A.PadIfNeeded(min_height=1024, min_width=1024, border_mode=4, value=None, mask_value=None, p=1.0),
])

transform_plot(image, transform)

# %% [markdown]
# <a id="lambda"></a>
# # Lambda

# %%
transform = A.Compose([
    A.Lambda(p=1.0),
])

transform_plot(image, transform)
